# %% [markdown]
# # Kinematics exercises

# %% [markdown]
# ## Exercise 1
# In this first exercise, you are been provided with a file containing data of right ankle and right knee
# displacements during three strides of walking of an adult. The file contains seven columns: time, x, y, and
# z-axes of knee, and x, y, and z-axes of ankle. Here is adopted the convention of Jeff’s lab and z-axis is
# parallel to gravity. Calculate:
#
# 1. Linear velocity of the ankle.
# 2. Linear acceleration of the ankle.
# 3. 2D Angle between the leg and the floor.
# 4. Angular velocity of the ankle. (Consider the knee marker as the rotation axis).
#   1. Calculate it using only x and z-axes.
#   2. Calculate it using x, y, and z-axes.
#   3. Plot both results. Are they different? If yes, why?
# 5. Angular acceleration of the ankle relative to the ground using result of item 4.b.

# %%
import pandas as pd
import numpy as np
# Out:
# /home/hen/miniconda3/envs/python33/lib/python3.3/site-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))

# %%
# Load data
# Note: not necessary to use os module since this notebook is in the same directory as the data.
# !ls
# Out:
# 1-walking.ipynb  CESPA Summer Course - Exercises.pdf  walk0001.txt

# %%
# !head walk0001.txt -n 20
# Out:
# NO_OF_FRAMES	720
# NO_OF_CAMERAS	7
# NO_OF_MARKERS	2
# FREQUENCY	120
# NO_OF_ANALOG	0
# ANALOG_FREQUENCY	0
# DESCRIPTION	--
# TIME_STAMP	2014-06-17, 08:53:44	912.56663253
# DATA_INCLUDED	3D
# MARKER_NAMES	right_knee	right_ankle
# Frame	Time	right_knee X	right_knee Y	right_knee Z	right_ankle X	right_ankle Y	right_ankle Z
# 1	0.00833	1440.857	2052.804	474.694	1501.102	2073.985	102.815
# 2	0.01667	1440.625	2052.820	474.753	1501.187	2074.183	103.058
# 3	0.02500	1434.826	2054.241	482.904	1501.052	2073.905	102.775
# 4	0.03333	1435.092	2051.464	481.212	1501.557	2073.970	103.195
# 5	0.04167	1435.118	2051.504	481.120	1501.425	2073.629	102.974
# 6	0.05000	1435.160	2051.429	481.170	1501.329	2073.551	102.924
# 7	0.05833	1435.151	2051.393	481.199	1501.474	2073.784	103.147
# 8	0.06667	1429.771	2041.574	479.407	1501.732	2073.681	103.320
# 9	0.07500	1429.990	2041.554	479.591	1501.312	2073.741	103.047

# %%
df = pd.read_table('walk0001.txt',
                   sep='\t',
                   header=10)
df.head()
# Out:
#    Frame     Time  right_knee X  right_knee Y  right_knee Z  right_ankle X  \
# 0      1  0.00833      1440.857      2052.804       474.694       1501.102
# 1      2  0.01667      1440.625      2052.820       474.753       1501.187
# 2      3  0.02500      1434.826      2054.241       482.904       1501.052
# 3      4  0.03333      1435.092      2051.464       481.212       1501.557
# 4      5  0.04167      1435.118      2051.504       481.120       1501.425
#
#    right_ankle Y  right_ankle Z  Unnamed: 8
# 0       2073.985        102.815         NaN
# 1       2074.183        103.058         NaN
# 2       2073.905        102.775         NaN
# 3       2073.970        103.195         NaN
# 4       2073.629        102.974         NaN

# %%
df.columns
# Out:
# Index(['Frame', 'Time', 'right_knee X', 'right_knee Y', 'right_knee Z', 'right_ankle X', 'right_ankle Y', 'right_ankle Z', 'Unnamed: 8'], dtype='object')

# %%
del df['Unnamed: 8']
del df['Frame']

# %%
df.head()
# Out:
#       Time  right_knee X  right_knee Y  right_knee Z  right_ankle X  \
# 0  0.00833      1440.857      2052.804       474.694       1501.102
# 1  0.01667      1440.625      2052.820       474.753       1501.187
# 2  0.02500      1434.826      2054.241       482.904       1501.052
# 3  0.03333      1435.092      2051.464       481.212       1501.557
# 4  0.04167      1435.118      2051.504       481.120       1501.425
#
#    right_ankle Y  right_ankle Z
# 0       2073.985        102.815
# 1       2074.183        103.058
# 2       2073.905        102.775
# 3       2073.970        103.195
# 4       2073.629        102.974

# %% [markdown]
# ### Calculate ankle linear velocity

# %%
ankle = df.ix[:, ('Time', 'right_ankle X', 'right_ankle Y', 'right_ankle Z')]
ankle.head()
# Out:
#       Time  right_ankle X  right_ankle Y  right_ankle Z
# 0  0.00833       1501.102       2073.985        102.815
# 1  0.01667       1501.187       2074.183        103.058
# 2  0.02500       1501.052       2073.905        102.775
# 3  0.03333       1501.557       2073.970        103.195
# 4  0.04167       1501.425       2073.629        102.974

# %%
ankle.columns = ['t', 'x', 'y', 'z']
ankle.head()
# Out:
#          t         x         y        z
# 0  0.00833  1501.102  2073.985  102.815
# 1  0.01667  1501.187  2074.183  103.058
# 2  0.02500  1501.052  2073.905  102.775
# 3  0.03333  1501.557  2073.970  103.195
# 4  0.04167  1501.425  2073.629  102.974

# %%
def difference(frame, columns=None, in_place=False):
    """Differentiate multiple columns from a data frame.
    Differences are appended with prefix 'd'.
    
    Parameters
    ----------
    frame : DataFrame
        DataFrame to operate on.
    colums : list of str, optional
        Columns to difference.
        If not given, all columns will be differenced.
    in_place : bool, optional
        If True, add columns in-place.
        
    """
    if not in_place:
        frame = frame.copy()
    
    if columns is None:
        columns = frame.columns
        
    for column in columns:
        frame['d' + column] = frame[column].diff()
    
    return frame

# %%
ankle = difference(ankle)
ankle.head()
# Out:
#          t         x         y        z       dt     dx     dy     dz
# 0  0.00833  1501.102  2073.985  102.815      NaN    NaN    NaN    NaN
# 1  0.01667  1501.187  2074.183  103.058  0.00834  0.085  0.198  0.243
# 2  0.02500  1501.052  2073.905  102.775  0.00833 -0.135 -0.278 -0.283
# 3  0.03333  1501.557  2073.970  103.195  0.00833  0.505  0.065  0.420
# 4  0.04167  1501.425  2073.629  102.974  0.00834 -0.132 -0.341 -0.221

# %%
ankle['displacement'] = np.linalg.norm(ankle.ix[:,('dx', 'dy', 'dz')], axis=1)

# %%
ankle.head()
# Out:
#          t         x         y        z       dt     dx     dy     dz  \
# 0  0.00833  1501.102  2073.985  102.815      NaN    NaN    NaN    NaN
# 1  0.01667  1501.187  2074.183  103.058  0.00834  0.085  0.198  0.243
# 2  0.02500  1501.052  2073.905  102.775  0.00833 -0.135 -0.278 -0.283
# 3  0.03333  1501.557  2073.970  103.195  0.00833  0.505  0.065  0.420
# 4  0.04167  1501.425  2073.629  102.974  0.00834 -0.132 -0.341 -0.221
#
#    displacement
# 0           NaN
# 1      0.324774
# 2      0.419044
# 3      0.660038
# 4      0.427254

# %%
ankle['speed'] = ankle['displacement'] / ankle['dt']

# %%
def process_3d_point(frame, in_place=False):
    """
    Given a DataFrame of a 3D point
    with columns ('x', 'y', 'z', 't'),
    calculate and add columns
    ('dx', 'dy', 'dz', 'dt', 'displacement', 'speed', 'accel').
    
    Parameters
    ----------
    frame : DataFrame
        Data to process.
    in_place : bool, optional
        If True, operate in-place.
    
    """
    if not in_place:
        frame = frame.copy()
        
    difference(frame, ('t', 'x', 'y', 'z'), in_place=True)
    frame['displacement'] = np.linalg.norm(frame.ix[:, ('dx', 'dy', 'dz')], axis=1)
    frame['speed'] = frame['displacement'] / frame['dt']
    frame['accel'] = frame['speed'].diff() / frame['dt']
    
    return frame

# %%
ankle = df.ix[:, ('Time', 'right_ankle X', 'right_ankle Y', 'right_ankle Z')]
ankle.columns = ['t', 'x', 'y', 'z']
ankle = process_3d_point(ankle)
ankle.head()
# Out:
#          t         x         y        z       dt     dx     dy     dz  \
# 0  0.00833  1501.102  2073.985  102.815      NaN    NaN    NaN    NaN
# 1  0.01667  1501.187  2074.183  103.058  0.00834  0.085  0.198  0.243
# 2  0.02500  1501.052  2073.905  102.775  0.00833 -0.135 -0.278 -0.283
# 3  0.03333  1501.557  2073.970  103.195  0.00833  0.505  0.065  0.420
# 4  0.04167  1501.425  2073.629  102.974  0.00834 -0.132 -0.341 -0.221
#
#    displacement      speed        accel
# 0           NaN        NaN          NaN
# 1      0.324774  38.941699          NaN
# 2      0.419044  50.305420  1364.192255
# 3      0.660038  79.236240  3473.087587
# 4      0.427254  51.229499 -3358.122384

# %%
knee = df.ix[:, ('Time', 'right_knee X', 'right_knee Y', 'right_knee Z')]
knee.columns = ['t', 'x', 'y', 'z']
knee = process_3d_point(knee)
knee.head()
# Out:
#          t         x         y        z       dt     dx     dy     dz  \
# 0  0.00833  1440.857  2052.804  474.694      NaN    NaN    NaN    NaN
# 1  0.01667  1440.625  2052.820  474.753  0.00834 -0.232  0.016  0.059
# 2  0.02500  1434.826  2054.241  482.904  0.00833 -5.799  1.421  8.151
# 3  0.03333  1435.092  2051.464  481.212  0.00833  0.266 -2.777 -1.692
# 4  0.04167  1435.118  2051.504  481.120  0.00834  0.026  0.040 -0.092
#
#    displacement        speed          accel
# 0           NaN          NaN            NaN
# 1      0.239919    28.767235            NaN
# 2     10.103784  1212.939207  142157.499749
# 3      3.262721   391.683206  -98590.156273
# 4      0.103634    12.426136  -45474.468834

# %%
leg = knee.ix[:, 'x':'z'] - ankle.ix[:, 'x':'z']
leg[['t', 'dt']] = ankle[['t', 'dt']]
leg.head()
# Out:
#         x       y        z        t       dt
# 0 -60.245 -21.181  371.879  0.00833      NaN
# 1 -60.562 -21.363  371.695  0.01667  0.00834
# 2 -66.226 -19.664  380.129  0.02500  0.00833
# 3 -66.465 -22.506  378.017  0.03333  0.00833
# 4 -66.307 -22.125  378.146  0.04167  0.00834

# %%
leg['angle'] = np.arctan2(leg['z'], np.linalg.norm(leg.ix[:, 'x':'y'], axis=1))
leg.head()
# Out:
#         x       y        z        t       dt     angle
# 0 -60.245 -21.181  371.879  0.00833      NaN  1.400733
# 1 -60.562 -21.363  371.695  0.01667  0.00834  1.399711
# 2 -66.226 -19.664  380.129  0.02500  0.00833  1.391021
# 3 -66.465 -22.506  378.017  0.03333  0.00833  1.387254
# 4 -66.307 -22.125  378.146  0.04167  0.00834  1.388008

# %%
leg['length'] = np.linalg.norm(leg.ix[:, 'x':'z'], axis=1)
leg['d_angle_dt'] = (leg['angle'].diff() / leg['length'] )/ leg['dt']
leg.head()
# Out:
#         x       y        z        t       dt     angle      length  d_angle_dt
# 0 -60.245 -21.181  371.879  0.00833      NaN  1.400733  377.322257         NaN
# 1 -60.562 -21.363  371.695  0.01667  0.00834  1.399711  377.201944   -0.000325
# 2 -66.226 -19.664  380.129  0.02500  0.00833  1.391021  386.355552   -0.002700
# 3 -66.465 -22.506  378.017  0.03333  0.00833  1.387254  384.474926   -0.001176
# 4 -66.307 -22.125  378.146  0.04167  0.00834  1.388008  384.552378    0.000235

# %%
leg['dd_angle_dt'] = leg['d_angle_dt'].diff() / leg['dt']
leg.head()
# Out:
#         x       y        z        t       dt     angle      length  \
# 0 -60.245 -21.181  371.879  0.00833      NaN  1.400733  377.322257
# 1 -60.562 -21.363  371.695  0.01667  0.00834  1.399711  377.201944
# 2 -66.226 -19.664  380.129  0.02500  0.00833  1.391021  386.355552
# 3 -66.465 -22.506  378.017  0.03333  0.00833  1.387254  384.474926
# 4 -66.307 -22.125  378.146  0.04167  0.00834  1.388008  384.552378
#
#    d_angle_dt  dd_angle_dt
# 0         NaN          NaN
# 1   -0.000325          NaN
# 2   -0.002700    -0.285153
# 3   -0.001176     0.182928
# 4    0.000235     0.169255
